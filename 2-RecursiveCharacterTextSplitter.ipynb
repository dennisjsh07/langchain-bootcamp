# %% [markdown]
# ### Text Splitting using langchain_text_splitters
# https://docs.langchain.com/oss/python/integrations/splitters

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("samplePdf.pdf")
docs = loader.load()    
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content="Billable152\x0000hNon Billable80\x0000hTotal232\x0000h\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in pages,\nbv's, and ruleset's required for\nvendor registration and modification\nprocess.f\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in pages,\nbv's, and ruleset's required for\nvendor registration and modification\nprocess.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved satuday. DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved Friday. DJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring roles, fixing bugs in\npages and bv's for the\nimplementation of permission\nengine.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nbug fixing and configuring pages,\nbv's and rulesets required for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, ruleset's and\nworkflow's for registration,\nmodification flows.\nDJDennis Joshua\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n04\x000004\x000000\x0000\n04\x000004\x000000\x0000\n08\x000008\x000000\x0000\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nYSR-T1300 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\n\uedfd 30-11-2025\ue94d\n\uedfd 29-11-2025\ue94d\n\uedfd 28-11-2025\ue94d\n\uedfd 27-11-2025\ue94d\n\uedfd 26-11-2025\ue94d\n\uedfd 25-11-2025\ue94d\n\uedfd 24-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, ruleset's\nrequired for registration,\nmodification etc.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved casual leave DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved saturday DJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T7 Leave (Personal)\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\n\uedfd 23-11-2025\ue94d\n\uedfd 22-11-2025\ue94d\n\uedfd 21-11-2025\ue94d\n\uedfd 20-11-2025\ue94d\n\uedfd 19-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content="Yasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages,\nbusinessview's , rulesets and\nworklfows for registration and\nmodification process\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable Approved configuring and testing the new\npermission engine configuration.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable Approved configuring and testing the new\npermission engine configuration.\nDJDennis Joshua\nYasref SCH\nImplementation\n02\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in page,\nbv's , rulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n02\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in page,\nbv's , rulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved saturday DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved Friday. DJDennis Joshua\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\n\uedfd 18-11-2025\ue94d\n\uedfd 17-11-2025\ue94d\n\uedfd 16-11-2025\ue94d\n\uedfd 15-11-2025\ue94d\n\uedfd 14-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved sick leave DJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable\nApproved saturday DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable\nApproved friday DJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nHLB-T7 Leave (Personal)\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\n\uedfd 13-11-2025\ue94d\n\uedfd 12-11-2025\ue94d\n\uedfd 11-11-2025\ue94d\n\uedfd 10-11-2025\ue94d\n\uedfd 09-11-2025\ue94d\n\uedfd 08-11-2025\ue94d\n\uedfd 07-11-2025\ue94d\n\uedfd 06-11-2025\ue94d\n\uedfd 05-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved saturday. DJDennis Joshua\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\n\uedfd 04-11-2025\ue94d\n\uedfd 03-11-2025\ue94d\n\uedfd 02-11-2025\ue94d\n\uedfd 01-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM")]

# %% [markdown]
# ##### Recursively split text by characters

# %%
# recursive text splitter

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(docs) # here incoming format is already a document
texts
# Out:
# [Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content="Billable152\x0000hNon Billable80\x0000hTotal232\x0000h\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in pages,\nbv's, and ruleset's required for\nvendor registration and modification\nprocess.f\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in pages,\nbv's, and ruleset's required for\nvendor registration and modification\nprocess.\nDJDennis Joshua\nHolidays and\nLeave [Only]"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content="DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved satuday. DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved Friday. DJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring roles, fixing bugs in\npages and bv's for the\nimplementation of permission\nengine.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content="04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nbug fixing and configuring pages,\nbv's and rulesets required for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, ruleset's and\nworkflow's for registration,\nmodification flows.\nDJDennis Joshua\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n04\x000004\x000000\x0000\n04\x000004\x000000\x0000\n08\x000008\x000000\x0000\nYSR-T760 UT, SIT - QA\ue9b2"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='08\x000008\x000000\x0000\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nYSR-T1300 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\n\uedfd 30-11-2025\ue94d\n\uedfd 29-11-2025\ue94d\n\uedfd 28-11-2025\ue94d\n\uedfd 27-11-2025\ue94d\n\uedfd 26-11-2025\ue94d\n\uedfd 25-11-2025\ue94d\n\uedfd 24-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Supply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, ruleset's\nrequired for registration,\nmodification etc.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved casual leave DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved saturday DJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content="Approved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content="DJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content="Approved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T7 Leave (Personal)\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\n\uedfd 23-11-2025\ue94d\n\uedfd 22-11-2025\ue94d\n\uedfd 21-11-2025\ue94d\n\uedfd 20-11-2025\ue94d\n\uedfd 19-11-2025\ue94d"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content='\uedfd 21-11-2025\ue94d\n\uedfd 20-11-2025\ue94d\n\uedfd 19-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content="Yasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing permission\nengine flow for pages, bv's and\nrulesets.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages, bv's,\nrulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and testing pages,"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content="Approved\nconfiguring and testing pages,\nbusinessview's , rulesets and\nworklfows for registration and\nmodification process\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable Approved configuring and testing the new\npermission engine configuration.\nDJDennis Joshua\nYasref SCH\nImplementation\n04\x0000 DJDennis Joshua - 5000059 Billable Approved configuring and testing the new\npermission engine configuration.\nDJDennis Joshua\nYasref SCH\nImplementation"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content="DJDennis Joshua\nYasref SCH\nImplementation\n02\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in page,\nbv's , rulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nYasref SCH\nImplementation\n02\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring and fixing bugs in page,\nbv's , rulesets and workflow's for\nregistration and modification\nprocess.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content='Leave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved saturday DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved Friday. DJDennis Joshua\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\nYSR-T1299 UT, SIT - Dev\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content='HLB-T5 Holiday - Weekend\ue9b2\n\uedfd 18-11-2025\ue94d\n\uedfd 17-11-2025\ue94d\n\uedfd 16-11-2025\ue94d\n\uedfd 15-11-2025\ue94d\n\uedfd 14-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved sick leave DJDennis Joshua\nYasref SCH"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets,\nworkflow's required for registration\nand modification process.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable\nApproved saturday DJDennis Joshua\nHolidays and"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content="Approved saturday DJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable\nApproved friday DJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\n08\x000000\x000008\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\nYSR-T760 UT, SIT - QA\ue9b2"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content='08\x000008\x000000\x0000\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nHLB-T7 Leave (Personal)\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\nYSR-T1220 UT, SIT - QA\ue9b2\n\uedfd 13-11-2025\ue94d\n\uedfd 12-11-2025\ue94d\n\uedfd 11-11-2025\ue94d\n\uedfd 10-11-2025\ue94d\n\uedfd 09-11-2025\ue94d\n\uedfd 08-11-2025\ue94d\n\uedfd 07-11-2025\ue94d\n\uedfd 06-11-2025\ue94d\n\uedfd 05-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content='Supply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM'),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content="Yasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content="Approved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nYasref SCH\nImplementation\n08\x0000 DJDennis Joshua - 5000059 Billable\nApproved\nconfiguring pages, bv's, rulesets and\nintegrations for registration and\nonboarding process.\nDJDennis Joshua\nHolidays and\nLeave [Only]\n08\x0000 DJDennis Joshua - 5000059 Non\nBillable Approved saturday. DJDennis Joshua\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000008\x000000\x0000\n08\x000000\x000008\x0000\nYSR-T760 UT, SIT - QA\ue9b2"),
#  Document(metadata={'producer': 'Skia/PDF m118', 'creator': 'Chromium', 'creationdate': '2025-12-04T07:07:18+00:00', 'moddate': '2025-12-04T07:07:18+00:00', 'source': 'samplePdf.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content='08\x000000\x000008\x0000\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T760 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nYSR-T743 UT, SIT - QA\ue9b2\nHLB-T5 Holiday - Weekend\ue9b2\n\uedfd 04-11-2025\ue94d\n\uedfd 03-11-2025\ue94d\n\uedfd 02-11-2025\ue94d\n\uedfd 01-11-2025\ue94d\n\ue9b1Project \ue92cDaily Log Hours \ue92cTime Period \uea89User \uea21Billing…\uea21Approval Status \uea1eNotes \uea89Created By\ueb1a ID Log Title\nSupply Chain Hub\nTimesheet List view\nProject Name:All Projects View:Group By Date Custom View Name:My Time Logs Date:01-11-2025 to 30-11-2025 Exported On:04-12-2025 12\x0037 PM')]

# %%
# read speech.txt file

with open("speech.txt") as f:
    content = f.read()

content
# Out:
# 'Freedom was not gifted; it was earned through courage and sacrifice.\nCountless voices rose together to demand dignity and self-rule.\nEvery step toward independence carried the weight of hope and loss.\nThe struggle taught us unity beyond language, region, or belief.\nIndependence is not just a date, but a responsibility we carry daily.\nIt reminds us to protect justice, equality, and truth.\nThe past whispers lessons of resilience and bravery.\nThe present asks us to build with integrity and compassion.\nThe future depends on how wisely we use our freedom today.\nIndependence lives on when we choose progress over fear.\n'

# %%
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=50,
    chunk_overlap=20,
)

texts = text_splitter.create_documents([content]) # here incoming format is plain text
texts
# Out:
# [Document(metadata={}, page_content='Freedom was not gifted; it was earned through'),
#  Document(metadata={}, page_content='was earned through courage and sacrifice.'),
#  Document(metadata={}, page_content='Countless voices rose together to demand dignity'),
#  Document(metadata={}, page_content='to demand dignity and self-rule.'),
#  Document(metadata={}, page_content='Every step toward independence carried the weight'),
#  Document(metadata={}, page_content='carried the weight of hope and loss.'),
#  Document(metadata={}, page_content='The struggle taught us unity beyond language,'),
#  Document(metadata={}, page_content='beyond language, region, or belief.'),
#  Document(metadata={}, page_content='Independence is not just a date, but a'),
#  Document(metadata={}, page_content='just a date, but a responsibility we carry daily.'),
#  Document(metadata={}, page_content='It reminds us to protect justice, equality, and'),
#  Document(metadata={}, page_content='equality, and truth.'),
#  Document(metadata={}, page_content='The past whispers lessons of resilience and'),
#  Document(metadata={}, page_content='of resilience and bravery.'),
#  Document(metadata={}, page_content='The present asks us to build with integrity and'),
#  Document(metadata={}, page_content='with integrity and compassion.'),
#  Document(metadata={}, page_content='The future depends on how wisely we use our'),
#  Document(metadata={}, page_content='wisely we use our freedom today.'),
#  Document(metadata={}, page_content='Independence lives on when we choose progress'),
#  Document(metadata={}, page_content='we choose progress over fear.')]

# %%
print(texts[0])
print(texts[1])
# Out:
# page_content='Freedom was not gifted; it was earned through'
# page_content='was earned through courage and sacrifice.'
